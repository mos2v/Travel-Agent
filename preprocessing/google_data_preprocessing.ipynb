# %%
import pandas as pd
import os

# %%
os.chdir(r"C:\Users\mosai\Desktop\GP papers\Travel-Agent")

# %%
df = pd.read_csv('data\places_details_raw.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\mosai\AppData\Local\Temp\ipykernel_33464\3723389030.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('data\places_details_raw.csv')
#                                  name                           id  \
# 0  places/ChIJg0IZSDt5TRQRVoRPioDGiMY  ChIJg0IZSDt5TRQRVoRPioDGiMY
# 1  places/ChIJh3exDCjF9RQR3xJz46pVXXA  ChIJh3exDCjF9RQR3xJz46pVXXA
# 2  places/ChIJKamZp-FLqxUR4o76ZTA47NE  ChIJKamZp-FLqxUR4o76ZTA47NE
# 3  places/ChIJKZPDWgC79xQR97MAX3mGZHk  ChIJKZPDWgC79xQR97MAX3mGZHk
# 4  places/ChIJTcMeB5wP9hQRxPyPlFiVmRE  ChIJTcMeB5wP9hQRxPyPlFiVmRE
#
#                                                types nationalPhoneNumber  \
# 0  ['tourist_attraction', 'point_of_interest', 'e...        011 40663325
# 1  ['tourist_attraction', 'point_of_interest', 'e...                 NaN
# 2  ['breakfast_restaurant', 'brunch_restaurant', ...        010 61480619
# 3  ['tourist_attraction', 'point_of_interest', 'e...                 NaN
# 4  ['japanese_restaurant', 'restaurant', 'food', ...                 NaN
#
#   internationalPhoneNumber                                   formattedAddress  \
# 0          +20 11 40663325  Makadi Bay, Hurghada 1, Red Sea Governorate 84...
# 1                      NaN  5 Ahmed Yehia, Fleming, El Raml 1, Alexandria ...
# 2          +20 10 61480619  Blue Hole Rd, Dahab, South Sinai Governorate 8...
# 3                      NaN  X556+7H3, Al Shora, Al Mahalah Al Kubra (Part ...
# 4                      NaN  دوران، البحيرة،،، R8XV+6CM, Al Abqain, Hosh Ei...
#
#                                    addressComponents  rating  \
# 0  [{'longText': 'Makadi Bay', 'shortText': 'Maka...     4.4
# 1  [{'longText': '5', 'shortText': '5', 'types': ...     4.4
# 2  [{'longText': 'Blue Hole Road', 'shortText': '...     4.9
# 3  [{'longText': 'X556+7H3', 'shortText': 'X556+7...     NaN
# 4  [{'longText': 'R8XV+6CM', 'shortText': 'R8XV+6...     NaN
#
#                                        googleMapsUri  \
# 0  https://maps.google.com/?cid=14305902471720961110
# 1   https://maps.google.com/?cid=8096721897530790623
# 2  https://maps.google.com/?cid=15126527028951158498
# 3   https://maps.google.com/?cid=8747264232103392247
# 4   https://maps.google.com/?cid=1268208977763630276
#
#                               websiteUri  ...  priceRange.endPrice.units  \
# 0      http://www.dolphinworldegypt.com/  ...                        NaN
# 1                                    NaN  ...                        NaN
# 2  https://www.facebook.com/elcafedelsur  ...                      100.0
# 3                                    NaN  ...                        NaN
# 4                                    NaN  ...                        NaN
#
#   regularOpeningHours.nextOpenTime currentOpeningHours.nextOpenTime  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    accessibilityOptions.wheelchairAccessibleRestroom  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   accessibilityOptions.wheelchairAccessibleSeating priceLevel  \
# 0                                              NaN        NaN
# 1                                              NaN        NaN
# 2                                              NaN        NaN
# 3                                              NaN        NaN
# 4                                              NaN        NaN
#
#   containingPlaces currentSecondaryOpeningHours regularSecondaryOpeningHours  \
# 0              NaN                          NaN                          NaN
# 1              NaN                          NaN                          NaN
# 2              NaN                          NaN                          NaN
# 3              NaN                          NaN                          NaN
# 4              NaN                          NaN                          NaN
#
#    currentOpeningHours.specialDays
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4128 entries, 0 to 4127
# Data columns (total 60 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   name                                               4128 non-null   object
#  1   id                                                 4128 non-null   object
#  2   types                                              4126 non-null   object
#  3   nationalPhoneNumber                                2594 non-null   object
#  4   internationalPhoneNumber                           2594 non-null   object
#  5   formattedAddress                                   4128 non-null   object
#  6   addressComponents                                  4128 non-null   object
#  7   rating                                             3753 non-null   float64
#  8   googleMapsUri                                      4128 non-null   object
#  9   websiteUri                                         1152 non-null   object
#  10  utcOffsetMinutes                                   4128 non-null   int64
#  11  adrFormatAddress                                   4128 non-null   object
#  12  businessStatus                                     4119 non-null   object
#  13  userRatingCount                                    3753 non-null   float64
#  14  iconMaskBaseUri                                    4128 non-null   object
#  15  iconBackgroundColor                                4128 non-null   object
#  16  primaryType                                        4070 non-null   object
#  17  shortFormattedAddress                              4126 non-null   object
#  18  photos                                             3513 non-null   object
#  19  pureServiceAreaBusiness                            4128 non-null   bool
#  20  plusCode.globalCode                                2137 non-null   object
#  21  plusCode.compoundCode                              2043 non-null   object
#  22  location.latitude                                  4128 non-null   float64
#  23  location.longitude                                 4128 non-null   float64
#  24  viewport.low.latitude                              4128 non-null   float64
#  25  viewport.low.longitude                             4128 non-null   float64
#  26  viewport.high.latitude                             4128 non-null   float64
#  27  viewport.high.longitude                            4128 non-null   float64
#  28  regularOpeningHours.openNow                        2968 non-null   object
#  29  regularOpeningHours.periods                        2968 non-null   object
#  30  regularOpeningHours.weekdayDescriptions            2968 non-null   object
#  31  regularOpeningHours.nextCloseTime                  1810 non-null   object
#  32  displayName.text                                   4128 non-null   object
#  33  displayName.languageCode                           4128 non-null   object
#  34  primaryTypeDisplayName.text                        4070 non-null   object
#  35  primaryTypeDisplayName.languageCode                4070 non-null   object
#  36  currentOpeningHours.openNow                        2968 non-null   object
#  37  currentOpeningHours.periods                        2968 non-null   object
#  38  currentOpeningHours.weekdayDescriptions            2968 non-null   object
#  39  currentOpeningHours.nextCloseTime                  1810 non-null   object
#  40  accessibilityOptions.wheelchairAccessibleParking   1004 non-null   object
#  41  accessibilityOptions.wheelchairAccessibleEntrance  1031 non-null   object
#  42  googleMapsLinks.directionsUri                      4128 non-null   object
#  43  googleMapsLinks.placeUri                           4128 non-null   object
#  44  googleMapsLinks.writeAReviewUri                    4119 non-null   object
#  45  googleMapsLinks.reviewsUri                         4119 non-null   object
#  46  googleMapsLinks.photosUri                          4128 non-null   object
#  47  priceRange.startPrice.currencyCode                 1183 non-null   object
#  48  priceRange.startPrice.units                        1183 non-null   float64
#  49  priceRange.endPrice.currencyCode                   1123 non-null   object
#  50  priceRange.endPrice.units                          1123 non-null   float64
#  51  regularOpeningHours.nextOpenTime                   334 non-null    object
#  52  currentOpeningHours.nextOpenTime                   334 non-null    object
#  53  accessibilityOptions.wheelchairAccessibleRestroom  805 non-null    object
#  54  accessibilityOptions.wheelchairAccessibleSeating   1034 non-null   object
#  55  priceLevel                                         882 non-null    object
#  56  containingPlaces                                   329 non-null    object
#  57  currentSecondaryOpeningHours                       90 non-null     object
#  58  regularSecondaryOpeningHours                       90 non-null     object
#  59  currentOpeningHours.specialDays                    1 non-null      object
# dtypes: bool(1), float64(10), int64(1), object(48)
# memory usage: 1.9+ MB

# %%
a = df.duplicated(subset='id')
a[a == True]
# Out:
# Series([], dtype: bool)

# %%
cols_to_drop = [ 'name', 'nationalPhoneNumber', 'addressComponents', 'utcOffsetMinutes', 'adrFormatAddress',                                   
'businessStatus', 'iconMaskBaseUri', 'iconBackgroundColor', 'photos', 'pureServiceAreaBusiness', 'plusCode.globalCode',                               
'plusCode.compoundCode', 'viewport.low.latitude', 'viewport.low.longitude', 'viewport.high.latitude', 'viewport.high.longitude',                        
'regularOpeningHours.openNow', 'regularOpeningHours.periods', 'regularOpeningHours.nextCloseTime', 'primaryTypeDisplayName.languageCode',              
'currentOpeningHours.openNow', 'currentOpeningHours.periods', 'currentOpeningHours.weekdayDescriptions', 'currentOpeningHours.nextCloseTime',             
'accessibilityOptions.wheelchairAccessibleParking', 'accessibilityOptions.wheelchairAccessibleEntrance', 'googleMapsLinks.directionsUri',                   
'googleMapsLinks.placeUri', 'googleMapsLinks.writeAReviewUri', 'googleMapsLinks.reviewsUri', 'googleMapsLinks.photosUri',                         
'priceRange.startPrice.currencyCode', 'priceRange.endPrice.currencyCode', 'regularOpeningHours.nextOpenTime', 'currentOpeningHours.nextOpenTime',                
'accessibilityOptions.wheelchairAccessibleRestroom', 'accessibilityOptions.wheelchairAccessibleSeating', 'currentSecondaryOpeningHours',         
'regularSecondaryOpeningHours', 'currentOpeningHours.specialDays', 'containingPlaces']

# %%
df = df.drop(columns=cols_to_drop, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4128 entries, 0 to 4127
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   id                                       4128 non-null   object
#  1   types                                    4126 non-null   object
#  2   internationalPhoneNumber                 2594 non-null   object
#  3   formattedAddress                         4128 non-null   object
#  4   rating                                   3753 non-null   float64
#  5   googleMapsUri                            4128 non-null   object
#  6   websiteUri                               1152 non-null   object
#  7   userRatingCount                          3753 non-null   float64
#  8   primaryType                              4070 non-null   object
#  9   shortFormattedAddress                    4126 non-null   object
#  10  location.latitude                        4128 non-null   float64
#  11  location.longitude                       4128 non-null   float64
#  12  regularOpeningHours.weekdayDescriptions  2968 non-null   object
#  13  displayName.text                         4128 non-null   object
#  14  displayName.languageCode                 4128 non-null   object
#  15  primaryTypeDisplayName.text              4070 non-null   object
#  16  priceRange.startPrice.units              1183 non-null   float64
#  17  priceRange.endPrice.units                1123 non-null   float64
#  18  priceLevel                               882 non-null    object
# dtypes: float64(6), object(13)
# memory usage: 612.9+ KB

# %%
df.head()
# Out:
#                             id  \
# 0  ChIJg0IZSDt5TRQRVoRPioDGiMY
# 1  ChIJh3exDCjF9RQR3xJz46pVXXA
# 2  ChIJKamZp-FLqxUR4o76ZTA47NE
# 3  ChIJKZPDWgC79xQR97MAX3mGZHk
# 4  ChIJTcMeB5wP9hQRxPyPlFiVmRE
#
#                                                types internationalPhoneNumber  \
# 0  ['tourist_attraction', 'point_of_interest', 'e...          +20 11 40663325
# 1  ['tourist_attraction', 'point_of_interest', 'e...                      NaN
# 2  ['breakfast_restaurant', 'brunch_restaurant', ...          +20 10 61480619
# 3  ['tourist_attraction', 'point_of_interest', 'e...                      NaN
# 4  ['japanese_restaurant', 'restaurant', 'food', ...                      NaN
#
#                                     formattedAddress  rating  \
# 0  Makadi Bay, Hurghada 1, Red Sea Governorate 84...     4.4
# 1  5 Ahmed Yehia, Fleming, El Raml 1, Alexandria ...     4.4
# 2  Blue Hole Rd, Dahab, South Sinai Governorate 8...     4.9
# 3  X556+7H3, Al Shora, Al Mahalah Al Kubra (Part ...     NaN
# 4  دوران، البحيرة،،، R8XV+6CM, Al Abqain, Hosh Ei...     NaN
#
#                                        googleMapsUri  \
# 0  https://maps.google.com/?cid=14305902471720961110
# 1   https://maps.google.com/?cid=8096721897530790623
# 2  https://maps.google.com/?cid=15126527028951158498
# 3   https://maps.google.com/?cid=8747264232103392247
# 4   https://maps.google.com/?cid=1268208977763630276
#
#                               websiteUri  userRatingCount  \
# 0      http://www.dolphinworldegypt.com/           4167.0
# 1                                    NaN           2090.0
# 2  https://www.facebook.com/elcafedelsur             82.0
# 3                                    NaN              NaN
# 4                                    NaN              NaN
#
#            primaryType                              shortFormattedAddress  \
# 0   tourist_attraction                                         Hurghada 1
# 1   tourist_attraction                  5 Ahmed Yehia, Fleming, El Raml 1
# 2                 cafe                                Blue Hole Rd, Dahab
# 3   tourist_attraction  X556+7H3, Al Shora, Al Mahalah Al Kubra (Part ...
# 4  japanese_restaurant             R8XV+6CM، دوران، البحيرة،،, Hosh Eissa
#
#    location.latitude  location.longitude  \
# 0          26.990632           33.852096
# 1          31.238283           29.962784
# 2          28.508922           34.516042
# 3          30.958136           31.161437
# 4          30.848099           30.343551
#
#              regularOpeningHours.weekdayDescriptions  \
# 0  ['Monday: 10:30\u202fAM\u2009–\u20095:00\u202f...
# 1  ['Monday: Open 24 hours', 'Tuesday: Open 24 ho...
# 2  ['Monday: 8:00\u202fAM\u2009–\u200912:00\u202f...
# 3                                                NaN
# 4                                                NaN
#
#                                     displayName.text displayName.languageCode  \
# 0                                Dolphin World Egypt                       en
# 1                                              Gleem                       en
# 2  Cafe Del Sur (Cafe, Bakery & Art Gallery) - بن...                       en
# 3                                              المقر                       ar
# 4               رست هاوس وادى النطرون مطعم لقمة هنية                       ar
#
#   primaryTypeDisplayName.text  priceRange.startPrice.units  \
# 0          Tourist Attraction                          NaN
# 1          Tourist Attraction                          NaN
# 2                        Cafe                          1.0
# 3          Tourist Attraction                          NaN
# 4         Japanese Restaurant                          NaN
#
#    priceRange.endPrice.units priceLevel
# 0                        NaN        NaN
# 1                        NaN        NaN
# 2                      100.0        NaN
# 3                        NaN        NaN
# 4                        NaN        NaN

# %%
df.to_csv('data/places_details.csv')
