# %%
import pandas as pd
import os
os.chdir(r"C:\Users\mosai\Desktop\GP papers\Travel-Agent")

# %%
prices = pd.read_csv('data/egypt.csv')
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Place             207 non-null    object
#  1   Egyptian          205 non-null    object
#  2   EgyptianStudent   205 non-null    object
#  3   Foreign           207 non-null    object
#  4   ForeignStudent    207 non-null    object
#  5   VisitingTimes     191 non-null    object
#  6   Governorate/City  207 non-null    object
# dtypes: object(7)
# memory usage: 11.4+ KB

# %%
prices.head()
# Out:
#                                            Place Egyptian EgyptianStudent  \
# 0                 Salah al-Din al-Ayyubi Citadel       60              30
# 1                            Baron Empain Palace       60              30
# 2                           Panorama of the Roof       30              30
# 3                               AI-Mu'izz Street       20              10
# 4  Madrasa of Sultan Hassan & Al-Rifa’i \nMosque        -               -
#
#   Foreign ForeignStudent          VisitingTimes Governorate/City
# 0     550            275  From 8:00am to 5:00pm            Cairo
# 1     220            110  From 9:00am to 6:00pm            Cairo
# 2     120            120                    NaN            Cairo
# 3     220            110  From 9:00am to 5:00pm            Cairo
# 4     220            110  From 9:00am to 5:00pm            Cairo

# %%
prices['Place'] = prices['Place'].astype(str).str.replace('\n', '', regex=True)

# %%
prices.head(10)
# Out:
#                                                Place Egyptian EgyptianStudent  \
# 0                     Salah al-Din al-Ayyubi Citadel       60              30
# 1                                Baron Empain Palace       60              30
# 2                               Panorama of the Roof       30              30
# 3                                   AI-Mu'izz Street       20              10
# 4        Madrasa of Sultan Hassan & Al-Rifa’i Mosque        -               -
# 5                                    Bayt al-Suhaymi       10               5
# 6                                        Bab Zuwayla       10               5
# 7         Madrasa- Mosque of Muhammad Abu   al-Dahab       10               5
# 8                             The Mawlawiyya Takiyya       10               5
# 9  Al-Ghuri Complex, The dome, The Sabil and The ...       10               5
#
#   Foreign ForeignStudent          VisitingTimes Governorate/City
# ...

# %%
cols_to_replace = ['Egyptian', 'EgyptianStudent', 'Foreign', 'ForeignStudent']

prices[cols_to_replace] = prices[cols_to_replace].replace('-', 0)
prices.head(20)
# Out:
#                                                 Place Egyptian  \
# 0                      Salah al-Din al-Ayyubi Citadel       60
# 1                                 Baron Empain Palace       60
# 2                                Panorama of the Roof       30
# 3                                    AI-Mu'izz Street       20
# 4         Madrasa of Sultan Hassan & Al-Rifa’i Mosque        0
# 5                                     Bayt al-Suhaymi       10
# 6                                         Bab Zuwayla       10
# 7          Madrasa- Mosque of Muhammad Abu   al-Dahab       10
# 8                              The Mawlawiyya Takiyya       10
# 9   Al-Ghuri Complex, The dome, The Sabil and The ...       10
# 10                                 Wikala of al-Ghuri       10
# 11                    Jamal Al-Din Al-Dhahabi's house       10
# 12                                    Ali Labib House       10
# 13                                 House of al-Harawy       10
# ...

# %%
prices.to_csv('data/egypt_v0.1.csv')
